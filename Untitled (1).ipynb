# %% [markdown]
# # PRÁCTICA FINAL APRENDIZAJE AUTOMÁTICO

# %% [markdown]
# ## Cristina Ballesteros Samas y Lucía Hernáez Magán

# %% [markdown]
# ### 0. Selección y carga de la base de datos

# %%
### Aquí meter una introducción poniendo porque hemos elegido esta base de datos y las 
### meter también las posibles preguntas que nos vamos a plantear y los
## problemas que queremos resolver...

# %% [markdown]
# Nuestro objetivo con este trabajo es evaluar como de bueno es el precio de un determinado apartamento según sus características. Para ello trataremos de implementar un algoritmo (trataremos de hacerlo tanto con una red neuronal como con otros métodos de clasificación como la regresión logística o el análisis discriminante) que nos permita clasificar los apartamentos en:
# - Precio justo: En los casos en los que el precio sea acorde a las características del apartamento.
# - Super Precio: En los casos en los que el apartamento tenga un precio inferior al esperado dado las características de este.
# - Timo: Cuando el precio sea demasiado alto para las características del piso.

# %% [markdown]
# Cargamos las librerías más comunes que vamos a utilizar, posteriormente cargaremos más en caso de que sean necesarias, y también cargamos la base de datos.

# %%
import numpy  as np  
import pandas as pd

# %%
df=pd.read_csv("airbnb-listings-extract.csv", sep =";")

# %%
df.head().T
# Out:
#                                                                                 0  \
# ID                                                                       11210388
# Listing Url                                 https://www.airbnb.com/rooms/11210388
# Scrape ID                                                          20170306202425
# Last Scraped                                                           2017-03-07
# Name                                               The Loft-Full Bath-Deck w/View
# ...                                                                           ...
# Cancellation Policy                                                      moderate
# Calculated host listings count                                                1.0
# Reviews per Month                                                             3.5
# Geolocation                                          30.3373609355,-97.8632766782
# Features                        Host Is Superhost,Host Has Profile Pic,Host Id...
#
#                                                                                 1  \
# ID                                                                       17471131
# Listing Url                                 https://www.airbnb.com/rooms/17471131
# Scrape ID                                                          20170407214050
# Last Scraped                                                           2017-04-08
# Name                                                   Claris I, Friendly Rentals
# ...                                                                           ...
# Cancellation Policy                                               super_strict_30
# Calculated host listings count                                              106.0
# Reviews per Month                                                            0.86
# Geolocation                                           41.3896829422,2.17262543017
# Features                        Host Has Profile Pic,Requires License,Instant ...
#
#                                                                                 2  \
# ID                                                                       17584891
# Listing Url                                 https://www.airbnb.com/rooms/17584891
# Scrape ID                                                          20170407214050
# Last Scraped                                                           2017-04-08
# Name                                          Style Terrace Red, Friendly Rentals
# ...                                                                           ...
# Cancellation Policy                                               super_strict_30
# Calculated host listings count                                              106.0
# Reviews per Month                                                             NaN
# Geolocation                                           41.3930345489,2.16217327868
# Features                        Host Has Profile Pic,Requires License,Instant ...
#
#                                                                                 3  \
# ID                                                                        5398030
# Listing Url                                  https://www.airbnb.com/rooms/5398030
# Scrape ID                                                          20170407214050
# Last Scraped                                                           2017-04-08
# Name                                            Picasso Suite 1.4 Paseo de Gracia
# ...                                                                           ...
# Cancellation Policy                                                        strict
# Calculated host listings count                                               24.0
# Reviews per Month                                                            1.09
# Geolocation                                            41.3969668101,2.1674178103
# Features                        Host Has Profile Pic,Host Identity Verified,Re...
#
#                                                                                 4
# ID                                                                       18104606
# Listing Url                                 https://www.airbnb.com/rooms/18104606
# Scrape ID                                                          20170407214050
# Last Scraped                                                           2017-04-08
# Name                                               Smart City Centre Apartment II
# ...                                                                           ...
# Cancellation Policy                                                      flexible
# Calculated host listings count                                               92.0
# Reviews per Month                                                             NaN
# Geolocation                                           41.3886851936,2.15514963616
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
#
# [89 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14780 entries, 0 to 14779
# Data columns (total 89 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              14780 non-null  int64
#  1   Listing Url                     14780 non-null  object
#  2   Scrape ID                       14780 non-null  int64
#  3   Last Scraped                    14780 non-null  object
#  4   Name                            14779 non-null  object
#  5   Summary                         14189 non-null  object
#  6   Space                           10888 non-null  object
#  7   Description                     14774 non-null  object
#  8   Experiences Offered             14780 non-null  object
#  9   Neighborhood Overview           9134 non-null   object
#  10  Notes                           5644 non-null   object
#  11  Transit                         9066 non-null   object
#  12  Access                          8318 non-null   object
#  13  Interaction                     8228 non-null   object
#  14  House Rules                     9619 non-null   object
#  15  Thumbnail Url                   11960 non-null  object
#  16  Medium Url                      11960 non-null  object
#  17  Picture Url                     14761 non-null  object
#  18  XL Picture Url                  11960 non-null  object
#  19  Host ID                         14780 non-null  int64
#  20  Host URL                        14780 non-null  object
#  21  Host Name                       14777 non-null  object
#  22  Host Since                      14777 non-null  object
#  23  Host Location                   14737 non-null  object
#  24  Host About                      9539 non-null   object
#  25  Host Response Time              12881 non-null  object
#  26  Host Response Rate              12881 non-null  float64
#  27  Host Acceptance Rate            39 non-null     object
#  28  Host Thumbnail Url              14777 non-null  object
#  29  Host Picture Url                14777 non-null  object
#  30  Host Neighbourhood              10904 non-null  object
#  31  Host Listings Count             14777 non-null  float64
#  32  Host Total Listings Count       14777 non-null  float64
#  33  Host Verifications              14774 non-null  object
#  34  Street                          14780 non-null  object
#  35  Neighbourhood                   9551 non-null   object
#  36  Neighbourhood Cleansed          14780 non-null  object
#  37  Neighbourhood Group Cleansed    13760 non-null  object
#  38  City                            14774 non-null  object
#  39  State                           14636 non-null  object
#  40  Zipcode                         14274 non-null  object
#  41  Market                          14723 non-null  object
#  42  Smart Location                  14780 non-null  object
#  43  Country Code                    14780 non-null  object
#  44  Country                         14779 non-null  object
#  45  Latitude                        14780 non-null  float64
#  46  Longitude                       14780 non-null  float64
#  47  Property Type                   14780 non-null  object
#  48  Room Type                       14780 non-null  object
#  49  Accommodates                    14780 non-null  int64
#  50  Bathrooms                       14725 non-null  float64
#  51  Bedrooms                        14755 non-null  float64
#  52  Beds                            14731 non-null  float64
#  53  Bed Type                        14780 non-null  object
#  54  Amenities                       14610 non-null  object
#  55  Square Feet                     598 non-null    float64
#  56  Price                           14763 non-null  float64
#  57  Weekly Price                    3590 non-null   float64
#  58  Monthly Price                   3561 non-null   float64
#  59  Security Deposit                6256 non-null   float64
#  60  Cleaning Fee                    8687 non-null   float64
#  61  Guests Included                 14780 non-null  int64
#  62  Extra People                    14780 non-null  int64
#  63  Minimum Nights                  14780 non-null  int64
#  64  Maximum Nights                  14780 non-null  int64
#  65  Calendar Updated                14780 non-null  object
#  66  Has Availability                12 non-null     object
#  67  Availability 30                 14780 non-null  int64
#  68  Availability 60                 14780 non-null  int64
#  69  Availability 90                 14780 non-null  int64
#  70  Availability 365                14780 non-null  int64
#  71  Calendar last Scraped           14780 non-null  object
#  72  Number of Reviews               14780 non-null  int64
#  73  First Review                    11618 non-null  object
#  74  Last Review                     11617 non-null  object
#  75  Review Scores Rating            11476 non-null  float64
#  76  Review Scores Accuracy          11454 non-null  float64
#  77  Review Scores Cleanliness       11460 non-null  float64
#  78  Review Scores Checkin           11443 non-null  float64
#  79  Review Scores Communication     11460 non-null  float64
#  80  Review Scores Location          11440 non-null  float64
#  81  Review Scores Value             11439 non-null  float64
#  82  License                         349 non-null    object
#  83  Jurisdiction Names              227 non-null    object
#  84  Cancellation Policy             14780 non-null  object
#  85  Calculated host listings count  14776 non-null  float64
#  86  Reviews per Month               11618 non-null  float64
#  87  Geolocation                     14780 non-null  object
#  88  Features                        14779 non-null  object
# dtypes: float64(23), int64(13), object(53)
# memory usage: 10.0+ MB

# %% [markdown]
# Observamos que nuestros datos están formados por 14780 observaciones y por 89 variables distintas de tipos int , object y float. Por tanto dada la gran cantidad de variables, nuestro primer objetivo será quedarnos únicamente con aquellas que sean significantes para nuestro análisis. La primera observación que hacemos es que existen algunas variables que tienen muchos datos nulos, por ello eliminamos todas las que tengan muchas observaciones nulas, estas son: 'Jurisdiction Names','License','Has Availability','Square Feet'y 'Host Acceptance Rate'.

# %%
df=df.drop([ 'Jurisdiction Names','License','Has Availability','Square Feet','Host Acceptance Rate'],axis=1)

# %% [markdown]
# A simple vista creemos que algunas de las variables no son relevantes en nuestro estudio así que las eliminamos:

# %%
df = df.drop(['Listing Url', 'Scrape ID', 'Last Scraped', 'Name', 'Summary',
              'Space', 'Description', 'Experiences Offered', 'Neighborhood Overview',
              'Notes', 'Transit', 'Access', 'Interaction', 'House Rules',
              'Thumbnail Url', 'Medium Url', 'Picture Url', 'XL Picture Url',
              'Host ID', 'Host URL', 'Host Name', 'Host Since', 'Host Location',
              'Host About', 'Host Response Time', 'Host Response Rate',
              'Host Thumbnail Url', 'Host Picture Url',
              'Host Neighbourhood', 'Host Listings Count',
              'Host Total Listings Count', 'Host Verifications','Neighbourhood Cleansed',
              'Neighbourhood Group Cleansed','Geolocation' ], axis=1)

# %%
df.head().T
# Out:
#                                                                                 0  \
# ID                                                                       11210388
# Street                          Canyon Edge Drive, Austin, TX 78733, United St...
# Neighbourhood                                                                 NaN
# City                                                                       Austin
# State                                                                          TX
# Zipcode                                                                     78733
# Market                                                                     Austin
# Smart Location                                                         Austin, TX
# Country Code                                                                   US
# Country                                                             United States
# Latitude                                                                30.337361
# Longitude                                                              -97.863277
# Property Type                                                                Loft
# Room Type                                                         Entire home/apt
# Accommodates                                                                    2
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Cable TV,Internet,Wireless Internet,Air con...
# Price                                                                        58.0
# Weekly Price                                                                  NaN
# Monthly Price                                                                 NaN
# Security Deposit                                                            100.0
# Cleaning Fee                                                                  NaN
# Guests Included                                                                 1
# Extra People                                                                    0
# Minimum Nights                                                                  2
# Maximum Nights                                                               1125
# Calendar Updated                                                            today
# Availability 30                                                                10
# Availability 60                                                                34
# Availability 90                                                                64
# Availability 365                                                              281
# Calendar last Scraped                                                  2017-03-06
# Number of Reviews                                                              42
# First Review                                                           2016-03-13
# Last Review                                                            2017-02-26
# Review Scores Rating                                                         98.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                                      moderate
# Calculated host listings count                                                1.0
# Reviews per Month                                                             3.5
# Features                        Host Is Superhost,Host Has Profile Pic,Host Id...
#
#                                                                                 1  \
# ID                                                                       17471131
# Street                                          Barcelona, Barcelona 08010, Spain
# Neighbourhood                                                                 NaN
# City                                                                    Barcelona
# State                                                                   Barcelona
# Zipcode                                                                     08010
# Market                                                                  Barcelona
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Country                                                                     Spain
# Latitude                                                                41.389683
# Longitude                                                                2.172625
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                    4
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Amenities                       Wireless Internet,Air conditioning,Elevator in...
# Price                                                                        70.0
# Weekly Price                                                                  NaN
# Monthly Price                                                                 NaN
# Security Deposit                                                            200.0
# Cleaning Fee                                                                 40.0
# Guests Included                                                                 2
# Extra People                                                                   44
# Minimum Nights                                                                  1
# Maximum Nights                                                               1125
# Calendar Updated                                                            today
# Availability 30                                                                 6
# Availability 60                                                                21
# Availability 90                                                                39
# Availability 365                                                              309
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                               1
# First Review                                                           2017-03-05
# Last Review                                                            2017-03-05
# Review Scores Rating                                                         80.0
# Review Scores Accuracy                                                        8.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                        8.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                               super_strict_30
# Calculated host listings count                                              106.0
# Reviews per Month                                                            0.86
# Features                        Host Has Profile Pic,Requires License,Instant ...
#
#                                                                                 2  \
# ID                                                                       17584891
# Street                                          Barcelona, Barcelona 08008, Spain
# Neighbourhood                                                                 NaN
# City                                                                    Barcelona
# State                                                                   Barcelona
# Zipcode                                                                     08008
# Market                                                                  Barcelona
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Country                                                                     Spain
# Latitude                                                                41.393035
# Longitude                                                                2.162173
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                    4
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Amenities                       Wireless Internet,Air conditioning,Elevator in...
# Price                                                                        70.0
# Weekly Price                                                                  NaN
# Monthly Price                                                                 NaN
# Security Deposit                                                            200.0
# Cleaning Fee                                                                 60.0
# Guests Included                                                                 2
# Extra People                                                                   42
# Minimum Nights                                                                  1
# Maximum Nights                                                               1125
# Calendar Updated                                                            today
# Availability 30                                                                 7
# Availability 60                                                                21
# Availability 90                                                                42
# Availability 365                                                              291
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                               0
# First Review                                                                  NaN
# Last Review                                                                   NaN
# Review Scores Rating                                                          NaN
# Review Scores Accuracy                                                        NaN
# Review Scores Cleanliness                                                     NaN
# Review Scores Checkin                                                         NaN
# Review Scores Communication                                                   NaN
# Review Scores Location                                                        NaN
# Review Scores Value                                                           NaN
# Cancellation Policy                                               super_strict_30
# Calculated host listings count                                              106.0
# Reviews per Month                                                             NaN
# Features                        Host Has Profile Pic,Requires License,Instant ...
#
#                                                                                 3  \
# ID                                                                        5398030
# Street                                          Barcelona, Barcelona 08009, Spain
# Neighbourhood                                                                 NaN
# City                                                                    Barcelona
# State                                                                   Barcelona
# Zipcode                                                                     08009
# Market                                                                  Barcelona
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Country                                                                     Spain
# Latitude                                                                41.396967
# Longitude                                                                2.167418
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                    8
# Bathrooms                                                                     2.0
# Bedrooms                                                                      3.0
# Beds                                                                          4.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Internet,Wireless Internet,Air conditioning...
# Price                                                                       229.0
# Weekly Price                                                                  NaN
# Monthly Price                                                                 NaN
# Security Deposit                                                            250.0
# Cleaning Fee                                                                 79.0
# Guests Included                                                                 2
# Extra People                                                                   39
# Minimum Nights                                                                  2
# Maximum Nights                                                               1125
# Calendar Updated                                                            today
# Availability 30                                                                11
# Availability 60                                                                24
# Availability 90                                                                47
# Availability 365                                                              316
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                              13
# First Review                                                           2016-04-17
# Last Review                                                            2017-03-02
# Review Scores Rating                                                         92.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                     9.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                               24.0
# Reviews per Month                                                            1.09
# Features                        Host Has Profile Pic,Host Identity Verified,Re...
#
#                                                                                 4
# ID                                                                       18104606
# Street                          L'Antiga Esquerra de l'Eixample, Barcelona, Ca...
# Neighbourhood                                     L'Antiga Esquerra de l'Eixample
# City                                                                    Barcelona
# State                                                                   Catalunya
# Zipcode                                                                     08036
# Market                                                                  Barcelona
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Country                                                                     Spain
# Latitude                                                                41.388685
# Longitude                                                                 2.15515
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                    5
# Bathrooms                                                                     1.0
# Bedrooms                                                                      2.0
# Beds                                                                          2.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Wireless Internet,Air conditioning,Kitchen,...
# Price                                                                       149.0
# Weekly Price                                                                  NaN
# Monthly Price                                                                 NaN
# Security Deposit                                                              NaN
# Cleaning Fee                                                                 55.0
# Guests Included                                                                 1
# Extra People                                                                    0
# Minimum Nights                                                                  2
# Maximum Nights                                                               1125
# Calendar Updated                                                            today
# Availability 30                                                                 0
# Availability 60                                                                 0
# Availability 90                                                                 0
# Availability 365                                                                7
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                               0
# First Review                                                                  NaN
# Last Review                                                                   NaN
# Review Scores Rating                                                          NaN
# Review Scores Accuracy                                                        NaN
# Review Scores Cleanliness                                                     NaN
# Review Scores Checkin                                                         NaN
# Review Scores Communication                                                   NaN
# Review Scores Location                                                        NaN
# Review Scores Value                                                           NaN
# Cancellation Policy                                                      flexible
# Calculated host listings count                                               92.0
# Reviews per Month                                                             NaN
# Features                        Host Has Profile Pic,Host Identity Verified,Is...

# %% [markdown]
# Hecho esto se nos ocurren algunas ideas para el resto de variables:
#    - Las variables que parecen ser más significativas para evaluar el precio son las siguientes: 'Property Type', 'Room Type', 'Accommodates', Bedrooms','Beds', 'Bathrooms', 'Neighbourhood', 'Amenities', 'Review Scores Rating' y 'Availability 365'.
#    - Combinar las variables de Review Scores y number of reviews para crear una nueva variable llamada valoración media.
#    - Estudiar todas las variables relativas al precio para calcular un precio único por día y por persona (sumando el precio de limpieza e incluyendo la posibilidad de que la fianza no sea devuelta).
#    - Tranformar y combunar algunas variables para facilitar el análisis, por ejemplo podemos sustituir las variables máximo y mínimo número de noches por otra variable llamada restricciones que valga 1 si existen restricciones y cero en caso contrario.
#
# Esto solo son unas primeras aproximaciones e hipotesis que comprobaremos posteriormente con los métodos correspondientes.

# %% [markdown]
# ### 1. Preparación de la base de datos. Análisis Exploratorio.

# %% [markdown]
# ### 1.1. Análisis Faltantes

# %% [markdown]
# Nuestro primer paso en el análisis exploratorio será estudiar la existencia de datos nulos y en su caso tratarlos.

# %%
df.isna().any()
# Out:
# ID                                False
# Street                            False
# Neighbourhood                      True
# City                               True
# State                              True
# Zipcode                            True
# Market                             True
# Smart Location                    False
# Country Code                      False
# Country                            True
# Latitude                          False
# Longitude                         False
# Property Type                     False
# Room Type                         False
# Accommodates                      False
# Bathrooms                          True
# Bedrooms                           True
# Beds                               True
# Bed Type                          False
# Amenities                          True
# Price                              True
# Weekly Price                       True
# Monthly Price                      True
# Security Deposit                   True
# Cleaning Fee                       True
# Guests Included                   False
# Extra People                      False
# Minimum Nights                    False
# Maximum Nights                    False
# Calendar Updated                  False
# Availability 30                   False
# Availability 60                   False
# Availability 90                   False
# Availability 365                  False
# Calendar last Scraped             False
# Number of Reviews                 False
# First Review                       True
# Last Review                        True
# Review Scores Rating               True
# Review Scores Accuracy             True
# Review Scores Cleanliness          True
# Review Scores Checkin              True
# Review Scores Communication        True
# Review Scores Location             True
# Review Scores Value                True
# Cancellation Policy               False
# Calculated host listings count     True
# Reviews per Month                  True
# Features                           True
# dtype: bool

# %% [markdown]
# Observamos que la gran mayoría de variables presentan datos nulos.
# De entre de entre las variables: 'Neighbourhood', 'City', 'State','Zipcode', 'Market'y'Smart Location', podemos eliminar todas salvo una pues nos aportan una información muy similar. Dado que la única que no presenta datos nulos es 'Smart Location' nos quedaremos con ella.

# %%
df = df.drop(['Neighbourhood', 'City', 'State','Zipcode', 'Market'], axis=1)

# %% [markdown]
# Además eliminamos la variable 'Country' por ser linealmente dependiente de 'Country Code' y presentra faltantes.

# %%
df = df.drop(['Country'], axis=1)

# %% [markdown]
# De entre el resto de variables que presentan datos nulos eliminamos además 'First Review' puesto que no es relevante cuando se hizo la primera review, sí lo es cuando se hizo la última. También eliminamos 'Reviews per Month'.

# %%
df = df.drop([ 'First Review', 'Reviews per Month'], axis=1)

# %%
df.isna().any()
# Out:
# ID                                False
# Street                            False
# Smart Location                    False
# Country Code                      False
# Latitude                          False
# Longitude                         False
# Property Type                     False
# Room Type                         False
# Accommodates                      False
# Bathrooms                          True
# Bedrooms                           True
# Beds                               True
# Bed Type                          False
# Amenities                          True
# Price                              True
# Weekly Price                       True
# Monthly Price                      True
# Security Deposit                   True
# Cleaning Fee                       True
# Guests Included                   False
# Extra People                      False
# Minimum Nights                    False
# Maximum Nights                    False
# Calendar Updated                  False
# Availability 30                   False
# Availability 60                   False
# Availability 90                   False
# Availability 365                  False
# Calendar last Scraped             False
# Number of Reviews                 False
# Last Review                        True
# Review Scores Rating               True
# Review Scores Accuracy             True
# Review Scores Cleanliness          True
# Review Scores Checkin              True
# Review Scores Communication        True
# Review Scores Location             True
# Review Scores Value                True
# Cancellation Policy               False
# Calculated host listings count     True
# Features                           True
# dtype: bool

# %% [markdown]
# Observamos que la lista de variables que presentan datos nulos se ha reducido, sin embargo; aún hay una gran cantidad de variables con missings. Para acabar con este problema usaremos la clase Imputer de sklearn y susutituiremos los datos nulos por la mediana. Este procedimiento solo sirve para las variables que no son objects, estás últimas las trataremos individualmente.

# %% [markdown]
# Antes de proceder con el algoritmo debemos tener en cuenta algunas caracteristicas que hasta ahora habiamos pasado por alto debido a que consideramos interesante incluirlas en el análisis de precios :
# - Las variables Weekly Price y Monthly Price presentaban aproximadamente un 25% de datos no nulos, una cifra muy baja que al imputar los faltantes posiblemente genere una distorsión de los resultados.
# - Las variable Security Deposit presenta menos del 50% de los datos no nulos, por lo que imputar faltantes también va a perjudicar a las predicciones.
#
# Por ello eliminamos de nuestro análisis estas tres variables.

# %%
df=df.drop(['Weekly Price','Monthly Price','Security Deposit'],axis=1)

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="median")

# %%
df_num = df.select_dtypes(exclude=['object'])
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14780 entries, 0 to 14779
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              14780 non-null  int64
#  1   Latitude                        14780 non-null  float64
#  2   Longitude                       14780 non-null  float64
#  3   Accommodates                    14780 non-null  int64
#  4   Bathrooms                       14725 non-null  float64
#  5   Bedrooms                        14755 non-null  float64
#  6   Beds                            14731 non-null  float64
#  7   Price                           14763 non-null  float64
#  8   Cleaning Fee                    8687 non-null   float64
#  9   Guests Included                 14780 non-null  int64
#  10  Extra People                    14780 non-null  int64
#  11  Minimum Nights                  14780 non-null  int64
#  12  Maximum Nights                  14780 non-null  int64
#  13  Availability 30                 14780 non-null  int64
#  14  Availability 60                 14780 non-null  int64
#  15  Availability 90                 14780 non-null  int64
#  16  Availability 365                14780 non-null  int64
#  17  Number of Reviews               14780 non-null  int64
#  18  Review Scores Rating            11476 non-null  float64
#  19  Review Scores Accuracy          11454 non-null  float64
#  20  Review Scores Cleanliness       11460 non-null  float64
#  21  Review Scores Checkin           11443 non-null  float64
#  22  Review Scores Communication     11460 non-null  float64
#  23  Review Scores Location          11440 non-null  float64
#  24  Review Scores Value             11439 non-null  float64
#  25  Calculated host listings count  14776 non-null  float64
# dtypes: float64(15), int64(11)
# memory usage: 2.9 MB

# %%
imputer.fit(df_num)
# Out:
# SimpleImputer(strategy='median')

# %%
df_num_nonan = imputer.transform(df_num)

# %%
df_ = pd.DataFrame(df_num_nonan, columns=df_num.columns)

# %%
df[df_num.columns]=df_
df.isna().any()
# Out:
# ID                                False
# Street                            False
# Smart Location                    False
# Country Code                      False
# Latitude                          False
# Longitude                         False
# Property Type                     False
# Room Type                         False
# Accommodates                      False
# Bathrooms                         False
# Bedrooms                          False
# Beds                              False
# Bed Type                          False
# Amenities                          True
# Price                             False
# Cleaning Fee                      False
# Guests Included                   False
# Extra People                      False
# Minimum Nights                    False
# Maximum Nights                    False
# Calendar Updated                  False
# Availability 30                   False
# Availability 60                   False
# Availability 90                   False
# Availability 365                  False
# Calendar last Scraped             False
# Number of Reviews                 False
# Last Review                        True
# Review Scores Rating              False
# Review Scores Accuracy            False
# Review Scores Cleanliness         False
# Review Scores Checkin             False
# Review Scores Communication       False
# Review Scores Location            False
# Review Scores Value               False
# Cancellation Policy               False
# Calculated host listings count    False
# Features                           True
# dtype: bool

# %% [markdown]
# Observamos que hemos conseguido eliminar los datos missing de las variables numéricas pero aún quedan los de las variables categóricas. Vamos a tratar de eliminarlos también.

# %%
df_cat_na=df[['Amenities', 'Last Review','Features']]
df_cat_na.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14780 entries, 0 to 14779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Amenities    14610 non-null  object
#  1   Last Review  11617 non-null  object
#  2   Features     14779 non-null  object
# dtypes: object(3)
# memory usage: 346.5+ KB

# %% [markdown]
# Observamos que la variable 'Last Review' presenta bastantes menos datos missing que las variables anteriormente eliminadas pero un gran número aún así. Por ello también la eliminamos. Por último para acabar definitivamente con los missings eliminamos las filas correspondientes a los datos nulos.

# %%
df=df.drop(['Last Review'], axis=1)

# %%
df=df.dropna()

# %%
df.isna().any()
# Out:
# ID                                False
# Street                            False
# Smart Location                    False
# Country Code                      False
# Latitude                          False
# Longitude                         False
# Property Type                     False
# Room Type                         False
# Accommodates                      False
# Bathrooms                         False
# Bedrooms                          False
# Beds                              False
# Bed Type                          False
# Amenities                         False
# Price                             False
# Cleaning Fee                      False
# Guests Included                   False
# Extra People                      False
# Minimum Nights                    False
# Maximum Nights                    False
# Calendar Updated                  False
# Availability 30                   False
# Availability 60                   False
# Availability 90                   False
# Availability 365                  False
# Calendar last Scraped             False
# Number of Reviews                 False
# Review Scores Rating              False
# Review Scores Accuracy            False
# Review Scores Cleanliness         False
# Review Scores Checkin             False
# Review Scores Communication       False
# Review Scores Location            False
# Review Scores Value               False
# Cancellation Policy               False
# Calculated host listings count    False
# Features                          False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14609 entries, 0 to 14779
# Data columns (total 37 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              14609 non-null  float64
#  1   Street                          14609 non-null  object
#  2   Smart Location                  14609 non-null  object
#  3   Country Code                    14609 non-null  object
#  4   Latitude                        14609 non-null  float64
#  5   Longitude                       14609 non-null  float64
#  6   Property Type                   14609 non-null  object
#  7   Room Type                       14609 non-null  object
#  8   Accommodates                    14609 non-null  float64
#  9   Bathrooms                       14609 non-null  float64
#  10  Bedrooms                        14609 non-null  float64
#  11  Beds                            14609 non-null  float64
#  12  Bed Type                        14609 non-null  object
#  13  Amenities                       14609 non-null  object
#  14  Price                           14609 non-null  float64
#  15  Cleaning Fee                    14609 non-null  float64
#  16  Guests Included                 14609 non-null  float64
#  17  Extra People                    14609 non-null  float64
#  18  Minimum Nights                  14609 non-null  float64
#  19  Maximum Nights                  14609 non-null  float64
#  20  Calendar Updated                14609 non-null  object
#  21  Availability 30                 14609 non-null  float64
#  22  Availability 60                 14609 non-null  float64
#  23  Availability 90                 14609 non-null  float64
#  24  Availability 365                14609 non-null  float64
#  25  Calendar last Scraped           14609 non-null  object
#  26  Number of Reviews               14609 non-null  float64
#  27  Review Scores Rating            14609 non-null  float64
#  28  Review Scores Accuracy          14609 non-null  float64
#  29  Review Scores Cleanliness       14609 non-null  float64
#  30  Review Scores Checkin           14609 non-null  float64
#  31  Review Scores Communication     14609 non-null  float64
#  32  Review Scores Location          14609 non-null  float64
#  33  Review Scores Value             14609 non-null  float64
#  34  Cancellation Policy             14609 non-null  object
#  35  Calculated host listings count  14609 non-null  float64
#  36  Features                        14609 non-null  object
# dtypes: float64(26), object(11)
# memory usage: 4.2+ MB

# %% [markdown]
# Finalmente hemos conseguido eliminar todo los datos missing y nos hemos quedado con 14609 observaciones y 37 variables.

# %% [markdown]
# ### 1.2. Análisis Duplicados

# %% [markdown]
# Prosiguiendo con nuestro análisis exploratorio estudiamos la existencia de datos duplicados y los eliminamos en caso de que sea necesario.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Observamos que no existen datos duplicados, por tanto no tenemos que eliminarlos.

# %% [markdown]
# ### 1.3. Tranformación de variables.

# %% [markdown]
# Hasta ahora hemos reducido la dimensionalidad de nuestro problema únicamente mediante metodos de seleccion filter de variables, es decir; únicamente hemos utilizado la información dada por las variables para seleccionar las que hemos considerado más adecuadas. En este apartado trataremos de seguir reduciendo la dimensionalidad pero ahora mediante la trasformación de algunas variables.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14609 entries, 0 to 14779
# Data columns (total 37 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              14609 non-null  float64
#  1   Street                          14609 non-null  object
#  2   Smart Location                  14609 non-null  object
#  3   Country Code                    14609 non-null  object
#  4   Latitude                        14609 non-null  float64
#  5   Longitude                       14609 non-null  float64
#  6   Property Type                   14609 non-null  object
#  7   Room Type                       14609 non-null  object
#  8   Accommodates                    14609 non-null  float64
#  9   Bathrooms                       14609 non-null  float64
#  10  Bedrooms                        14609 non-null  float64
#  11  Beds                            14609 non-null  float64
#  12  Bed Type                        14609 non-null  object
#  13  Amenities                       14609 non-null  object
#  14  Price                           14609 non-null  float64
#  15  Cleaning Fee                    14609 non-null  float64
#  16  Guests Included                 14609 non-null  float64
#  17  Extra People                    14609 non-null  float64
#  18  Minimum Nights                  14609 non-null  float64
#  19  Maximum Nights                  14609 non-null  float64
#  20  Calendar Updated                14609 non-null  object
#  21  Availability 30                 14609 non-null  float64
#  22  Availability 60                 14609 non-null  float64
#  23  Availability 90                 14609 non-null  float64
#  24  Availability 365                14609 non-null  float64
#  25  Calendar last Scraped           14609 non-null  object
#  26  Number of Reviews               14609 non-null  float64
#  27  Review Scores Rating            14609 non-null  float64
#  28  Review Scores Accuracy          14609 non-null  float64
#  29  Review Scores Cleanliness       14609 non-null  float64
#  30  Review Scores Checkin           14609 non-null  float64
#  31  Review Scores Communication     14609 non-null  float64
#  32  Review Scores Location          14609 non-null  float64
#  33  Review Scores Value             14609 non-null  float64
#  34  Cancellation Policy             14609 non-null  object
#  35  Calculated host listings count  14609 non-null  float64
#  36  Features                        14609 non-null  object
# dtypes: float64(26), object(11)
# memory usage: 4.2+ MB

# %%
import matplotlib.pyplot as plt
# Representar gráficamente la distribución de los atributos
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))

plt.subplot(1,3,1)
df['Bedrooms'].plot.hist(alpha=0.5, bins=25, grid = True)
plt.axis([0, 10, 0, 10000])
plt.xlabel('bedrooms')

plt.subplot(1,3,2)
df['Maximum Nights'].plot.hist(alpha=0.5, bins=25, grid = True)
plt.xlabel('Maximum Nights')

plt.subplot(1,3,3)
df['Minimum Nights'].plot.hist(alpha=0.5, bins=25, grid = True)
plt.xlabel('Minimum Nights')

plt.show()

# %% [markdown]
# Observamos que maximun nights y minimun nights parecen tomar muchos valores en 0.  Esto se puede interpretar como que no hay una restricción específica en la cantidad máxima de noches que un huésped puede reservar esa propiedad. En otras palabras, un huésped podría reservar esa propiedad por cualquier cantidad de noches, desde una sola noche hasta el tiempo que desee. Parece buena idea crear una nueva variable que me indique con valor 1 si la vivienda posee alguna restricccion del número de noches a reservar o si no.

# %%
# Crear una nueva columna llamada "Restriction" y establecerla como vacía
df["Restriction"] = ""

# Recorrer el DataFrame y asignar los valores correspondientes a la columna "Restriction"
for index, row in df.iterrows():
    if row["Maximum Nights"] == 0 and row["Minimum Nights"] == 0 :
        df.at[index, "Restriction"]==0
    else:
        df.at[index, "Restriction"] ==1

# Eliminat las columnas "Maximun Nights" y "Minimum Nights"
df=df.drop(["Maximum Nights", "Minimum Nights"], axis=1)
# Imprimir el DataFrame con la nueva columna
df.T
# Out:
#                                                                             0      \
# ID                                                                     11210388.0
# Street                          Canyon Edge Drive, Austin, TX 78733, United St...
# Smart Location                                                         Austin, TX
# Country Code                                                                   US
# Latitude                                                                30.337361
# Longitude                                                              -97.863277
# Property Type                                                                Loft
# Room Type                                                         Entire home/apt
# Accommodates                                                                  2.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Cable TV,Internet,Wireless Internet,Air con...
# Price                                                                        58.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                            today
# Availability 30                                                              10.0
# Availability 60                                                              34.0
# Availability 90                                                              64.0
# Availability 365                                                            281.0
# Calendar last Scraped                                                  2017-03-06
# Number of Reviews                                                            42.0
# Review Scores Rating                                                         98.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                                      moderate
# Calculated host listings count                                                1.0
# Features                        Host Is Superhost,Host Has Profile Pic,Host Id...
# Restriction
#
#                                                                             1      \
# ID                                                                     17471131.0
# Street                                          Barcelona, Barcelona 08010, Spain
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Latitude                                                                41.389683
# Longitude                                                                2.172625
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  4.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Amenities                       Wireless Internet,Air conditioning,Elevator in...
# Price                                                                        70.0
# Cleaning Fee                                                                 40.0
# Guests Included                                                               2.0
# Extra People                                                                 44.0
# Calendar Updated                                                            today
# Availability 30                                                               6.0
# Availability 60                                                              21.0
# Availability 90                                                              39.0
# Availability 365                                                            309.0
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                             1.0
# Review Scores Rating                                                         80.0
# Review Scores Accuracy                                                        8.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                        8.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                               super_strict_30
# Calculated host listings count                                              106.0
# Features                        Host Has Profile Pic,Requires License,Instant ...
# Restriction
#
#                                                                             2      \
# ID                                                                     17584891.0
# Street                                          Barcelona, Barcelona 08008, Spain
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Latitude                                                                41.393035
# Longitude                                                                2.162173
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  4.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Amenities                       Wireless Internet,Air conditioning,Elevator in...
# Price                                                                        70.0
# Cleaning Fee                                                                 60.0
# Guests Included                                                               2.0
# Extra People                                                                 42.0
# Calendar Updated                                                            today
# Availability 30                                                               7.0
# Availability 60                                                              21.0
# Availability 90                                                              42.0
# Availability 365                                                            291.0
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                             0.0
# Review Scores Rating                                                         94.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                               super_strict_30
# Calculated host listings count                                              106.0
# Features                        Host Has Profile Pic,Requires License,Instant ...
# Restriction
#
#                                                                             3      \
# ID                                                                      5398030.0
# Street                                          Barcelona, Barcelona 08009, Spain
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Latitude                                                                41.396967
# Longitude                                                                2.167418
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  8.0
# Bathrooms                                                                     2.0
# Bedrooms                                                                      3.0
# Beds                                                                          4.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Internet,Wireless Internet,Air conditioning...
# Price                                                                       229.0
# Cleaning Fee                                                                 79.0
# Guests Included                                                               2.0
# Extra People                                                                 39.0
# Calendar Updated                                                            today
# Availability 30                                                              11.0
# Availability 60                                                              24.0
# Availability 90                                                              47.0
# Availability 365                                                            316.0
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                            13.0
# Review Scores Rating                                                         92.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                     9.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                               24.0
# Features                        Host Has Profile Pic,Host Identity Verified,Re...
# Restriction
#
#                                                                             4      \
# ID                                                                     18104606.0
# Street                          L'Antiga Esquerra de l'Eixample, Barcelona, Ca...
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Latitude                                                                41.388685
# Longitude                                                                 2.15515
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  5.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      2.0
# Beds                                                                          2.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Wireless Internet,Air conditioning,Kitchen,...
# Price                                                                       149.0
# Cleaning Fee                                                                 55.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                            today
# Availability 30                                                               0.0
# Availability 60                                                               0.0
# Availability 90                                                               0.0
# Availability 365                                                              7.0
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                             0.0
# Review Scores Rating                                                         94.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                      flexible
# Calculated host listings count                                               92.0
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
# Restriction
#
#                                                                             5      \
# ID                                                                     15695269.0
# Street                          La Nova Esquerra de l'Eixample, Barcelona, Cat...
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Latitude                                                                41.382537
# Longitude                                                                2.149577
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  6.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      2.0
# Beds                                                                          3.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Wireless Internet,Air conditioning,Kitchen,...
# Price                                                                       106.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                      2 weeks ago
# Availability 30                                                               0.0
# Availability 60                                                               2.0
# Availability 90                                                               2.0
# Availability 365                                                              4.0
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                             0.0
# Review Scores Rating                                                         94.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                               92.0
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
# Restriction
#
#                                                                             6      \
# ID                                                                      1295958.0
# Street                           el Fort Pienc, Barcelona, Catalonia 08013, Spain
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Latitude                                                                41.399058
# Longitude                                                                2.184229
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  5.0
# Bathrooms                                                                     2.0
# Bedrooms                                                                      3.0
# Beds                                                                          4.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Internet,Wireless Internet,Air conditioning...
# Price                                                                        52.0
# Cleaning Fee                                                                 60.0
# Guests Included                                                               4.0
# Extra People                                                                 25.0
# Calendar Updated                                                            today
# Availability 30                                                               4.0
# Availability 60                                                              11.0
# Availability 90                                                              23.0
# Availability 365                                                            280.0
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                            43.0
# Review Scores Rating                                                         90.0
# Review Scores Accuracy                                                        9.0
# Review Scores Cleanliness                                                     9.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                        9.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                                1.0
# Features                        Host Has Profile Pic,Is Location Exact,Require...
# Restriction
#
#                                                                             7      \
# ID                                                                      1349311.0
# Street                          La Sagrada Família, Barcelona, Catalonia 08025...
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Latitude                                                                41.402357
# Longitude                                                                2.171119
# Property Type                                                           Apartment
# Room Type                                                            Private room
# Accommodates                                                                  2.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Internet,Wireless Internet,Air conditioning...
# Price                                                                        45.0
# Cleaning Fee                                                                 30.0
# Guests Included                                                               1.0
# Extra People                                                                 20.0
# Calendar Updated                                                        yesterday
# Availability 30                                                              13.0
# Availability 60                                                              38.0
# Availability 90                                                              66.0
# Availability 365                                                             66.0
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                            29.0
# Review Scores Rating                                                         96.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                                      flexible
# Calculated host listings count                                                1.0
# Features                        Host Has Profile Pic,Is Location Exact,Require...
# Restriction
#
#                                                                             8      \
# ID                                                                     15698621.0
# Street                          El Camp de l'Arpa del Clot, Barcelona, Catalun...
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Latitude                                                                41.407356
# Longitude                                                                2.182982
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  6.0
# Bathrooms                                                                     2.0
# Bedrooms                                                                      2.0
# Beds                                                                          3.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Wireless Internet,Air conditioning,Kitchen,...
# Price                                                                        80.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                       a week ago
# Availability 30                                                               0.0
# Availability 60                                                               0.0
# Availability 90                                                               2.0
# Availability 365                                                              2.0
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                             1.0
# Review Scores Rating                                                         80.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                        8.0
# Review Scores Value                                                           8.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                               92.0
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
# Restriction
#
#                                                                             9      \
# ID                                                                      6766647.0
# Street                              Enfield Road, Austin, TX 78703, United States
# Smart Location                                                         Austin, TX
# Country Code                                                                   US
# Latitude                                                                30.287124
# Longitude                                                              -97.768164
# Property Type                                                               House
# Room Type                                                         Entire home/apt
# Accommodates                                                                  6.0
# Bathrooms                                                                     2.0
# Bedrooms                                                                      3.0
# Beds                                                                          3.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Internet,Wireless Internet,Air conditioning...
# Price                                                                       795.0
# Cleaning Fee                                                                250.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                            today
# Availability 30                                                              21.0
# Availability 60                                                              51.0
# Availability 90                                                              81.0
# Availability 365                                                            356.0
# Calendar last Scraped                                                  2017-03-06
# Number of Reviews                                                             1.0
# Review Scores Rating                                                        100.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                                1.0
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
# Restriction
#
#                                 ...  \
# ID                              ...
# Street                          ...
# Smart Location                  ...
# Country Code                    ...
# Latitude                        ...
# Longitude                       ...
# Property Type                   ...
# Room Type                       ...
# Accommodates                    ...
# Bathrooms                       ...
# Bedrooms                        ...
# Beds                            ...
# Bed Type                        ...
# Amenities                       ...
# Price                           ...
# Cleaning Fee                    ...
# Guests Included                 ...
# Extra People                    ...
# Calendar Updated                ...
# Availability 30                 ...
# Availability 60                 ...
# Availability 90                 ...
# Availability 365                ...
# Calendar last Scraped           ...
# Number of Reviews               ...
# Review Scores Rating            ...
# Review Scores Accuracy          ...
# Review Scores Cleanliness       ...
# Review Scores Checkin           ...
# Review Scores Communication     ...
# Review Scores Location          ...
# Review Scores Value             ...
# Cancellation Policy             ...
# Calculated host listings count  ...
# Features                        ...
# Restriction                     ...
#
#                                                                             14770  \
# ID                                                                     16877299.0
# Street                                          Sineu, Illes Balears 07510, Spain
# Smart Location                                                       Sineu, Spain
# Country Code                                                                   ES
# Latitude                                                                39.646497
# Longitude                                                                2.992312
# Property Type                                                               House
# Room Type                                                         Entire home/apt
# Accommodates                                                                  8.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      3.0
# Beds                                                                          6.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Internet,Wireless Internet,Air conditioning...
# Price                                                                        90.0
# Cleaning Fee                                                                 60.0
# Guests Included                                                               6.0
# Extra People                                                                 20.0
# Calendar Updated                                                            today
# Availability 30                                                              17.0
# Availability 60                                                              43.0
# Availability 90                                                              73.0
# Availability 365                                                            348.0
# Calendar last Scraped                                                  2017-03-15
# Number of Reviews                                                             0.0
# Review Scores Rating                                                         94.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                                1.0
# Features                        Host Has Profile Pic,Host Identity Verified,Re...
# Restriction
#
#                                                                             14771  \
# ID                                                                      4152647.0
# Street                                        Pina, Balearic Islands 07220, Spain
# Smart Location                                                        Pina, Spain
# Country Code                                                                   ES
# Latitude                                                                39.595354
# Longitude                                                                2.927612
# Property Type                                                               House
# Room Type                                                         Entire home/apt
# Accommodates                                                                  2.0
# Bathrooms                                                                     2.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Wireless Internet,Pool,Kitchen,Free parking...
# Price                                                                       160.0
# Cleaning Fee                                                                 50.0
# Guests Included                                                               1.0
# Extra People                                                                 70.0
# Calendar Updated                                                     5 months ago
# Availability 30                                                              30.0
# Availability 60                                                              60.0
# Availability 90                                                              90.0
# Availability 365                                                            365.0
# Calendar last Scraped                                                  2017-03-15
# Number of Reviews                                                             0.0
# Review Scores Rating                                                         94.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                                3.0
# Features                                    Host Has Profile Pic,Requires License
# Restriction
#
#                                                                             14772  \
# ID                                                                      1501761.0
# Street                                       Petra, Balearic Islands 07520, Spain
# Smart Location                                                       Petra, Spain
# Country Code                                                                   ES
# Latitude                                                                39.604911
# Longitude                                                                3.097125
# Property Type                                                               House
# Room Type                                                         Entire home/apt
# Accommodates                                                                 10.0
# Bathrooms                                                                     4.0
# Bedrooms                                                                      4.0
# Beds                                                                          7.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Cable TV,Internet,Wireless Internet,Pool,Ki...
# Price                                                                       196.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                            today
# Availability 30                                                              30.0
# Availability 60                                                              60.0
# Availability 90                                                              90.0
# Availability 365                                                            316.0
# Calendar last Scraped                                                  2017-03-15
# Number of Reviews                                                             3.0
# Review Scores Rating                                                         80.0
# Review Scores Accuracy                                                        8.0
# Review Scores Cleanliness                                                     9.0
# Review Scores Checkin                                                         7.0
# Review Scores Communication                                                   5.0
# Review Scores Location                                                        9.0
# Review Scores Value                                                           8.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                              129.0
# Features                        Host Has Profile Pic,Host Identity Verified,Re...
# Restriction
#
#                                                                             14773  \
# ID                                                                      1010498.0
# Street                                  Balearic Islands, Balearic Islands, Spain
# Smart Location                                            Balearic Islands, Spain
# Country Code                                                                   ES
# Latitude                                                                39.740432
# Longitude                                                                2.931212
# Property Type                                                               House
# Room Type                                                         Entire home/apt
# Accommodates                                                                  8.0
# Bathrooms                                                                     3.0
# Bedrooms                                                                      4.0
# Beds                                                                          8.0
# Bed Type                                                                 Real Bed
# Amenities                       Cable TV,Wireless Internet,Air conditioning,Po...
# Price                                                                       260.0
# Cleaning Fee                                                                 60.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                            today
# Availability 30                                                              30.0
# Availability 60                                                              60.0
# Availability 90                                                              64.0
# Availability 365                                                            284.0
# Calendar last Scraped                                                  2017-03-15
# Number of Reviews                                                             0.0
# Review Scores Rating                                                         94.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                              129.0
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
# Restriction
#
#                                                                             14774  \
# ID                                                                      6292515.0
# Street                          Ditmars / Steinway, Queens, NY 11105, United S...
# Smart Location                                                         Queens, NY
# Country Code                                                                   US
# Latitude                                                                40.771787
# Longitude                                                              -73.898799
# Property Type                                                           Apartment
# Room Type                                                            Private room
# Accommodates                                                                  1.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Amenities                       Internet,Wireless Internet,Air conditioning,Ki...
# Price                                                                        40.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                    11 months ago
# Availability 30                                                               0.0
# Availability 60                                                               0.0
# Availability 90                                                               0.0
# Availability 365                                                              0.0
# Calendar last Scraped                                                  2017-05-02
# Number of Reviews                                                             1.0
# Review Scores Rating                                                         80.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# ...
# Calculated host listings count                                                1.0
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
# Restriction
#
#                                                                             14775  \
# ID                                                                      2098030.0
# Street                          Bedford-Stuyvesant, Brooklyn, NY 11213, United...
# Smart Location                                                       Brooklyn, NY
# Country Code                                                                   US
# Latitude                                                                40.678945
# Longitude                                                              -73.939342
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  2.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          2.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Cable TV,Internet,Wireless Internet,Air con...
# Price                                                                        90.0
# Cleaning Fee                                                                 60.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                       5 days ago
# Availability 30                                                               7.0
# Availability 60                                                              34.0
# Availability 90                                                              64.0
# Availability 365                                                            339.0
# Calendar last Scraped                                                  2017-05-02
# Number of Reviews                                                            30.0
# Review Scores Rating                                                         95.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                        9.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                                1.0
# Features                        Host Is Superhost,Host Has Profile Pic,Host Id...
# Restriction
#
#                                                                             14776  \
# ID                                                                     17989442.0
# Street                          Porte de Versailles, Paris, Île-de-France 7501...
# Smart Location                                                      Paris, France
# Country Code                                                                   FR
# Latitude                                                                48.836197
# Longitude                                                                2.294045
# Property Type                                                     Bed & Breakfast
# Room Type                                                            Private room
# Accommodates                                                                  1.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          2.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Wireless Internet,Kitchen,Breakfast,Elevato...
# Price                                                                        75.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                       3 days ago
# Availability 30                                                              17.0
# Availability 60                                                              47.0
# Availability 90                                                              77.0
# Availability 365                                                             78.0
# Calendar last Scraped                                                  2017-04-06
# Number of Reviews                                                             0.0
# Review Scores Rating                                                         94.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                      flexible
# Calculated host listings count                                                1.0
# Features                        Host Has Profile Pic,Is Location Exact,Instant...
# Restriction
#
#                                                                             14777  \
# ID                                                                     13278634.0
# Street                                               Paris, Île-de-France, France
# Smart Location                                                      Paris, France
# Country Code                                                                   FR
# Latitude                                                                48.888809
# Longitude                                                                2.316173
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  5.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      2.0
# Beds                                                                          3.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Cable TV,Internet,Wireless Internet,Air con...
# Price                                                                       100.0
# Cleaning Fee                                                                 40.0
# Guests Included                                                               3.0
# Extra People                                                                 10.0
# Calendar Updated                                                       5 days ago
# Availability 30                                                               7.0
# Availability 60                                                              18.0
# Availability 90                                                              29.0
# Availability 365                                                             97.0
# Calendar last Scraped                                                  2017-04-05
# Number of Reviews                                                            17.0
# Review Scores Rating                                                         94.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                                1.0
# Features                        Host Is Superhost,Host Has Profile Pic,Host Id...
# Restriction
#
#                                                                             14778  \
# ID                                                                     10733941.0
# Street                            Gaylord Street, Denver, CO 80206, United States
# Smart Location                                                         Denver, CO
# Country Code                                                                   US
# Latitude                                                                39.742205
# Longitude                                                             -104.959933
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  4.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          2.0
# Bed Type                                                                 Real Bed
# Amenities                       Internet,Wireless Internet,Kitchen,Heating,Was...
# Price                                                                        99.0
# Cleaning Fee                                                                 10.0
# Guests Included                                                               2.0
# Extra People                                                                 10.0
# Calendar Updated                                                        yesterday
# Availability 30                                                               0.0
# Availability 60                                                               0.0
# Availability 90                                                               0.0
# Availability 365                                                             14.0
# Calendar last Scraped                                                  2016-05-18
# Number of Reviews                                                             1.0
# Review Scores Rating                                                        100.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                                      moderate
# Calculated host listings count                                                1.0
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
# Restriction
#
#                                                                             14779
# ID                                                                      4637801.0
# Street                          35th Avenue Northeast, Seattle, WA 98105, Unit...
# Smart Location                                                        Seattle, WA
# Country Code                                                                   US
# Latitude                                                                47.672327
# Longitude                                                             -122.291451
# Property Type                                                               House
# Room Type                                                            Private room
# Accommodates                                                                  2.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Amenities                       TV,Cable TV,Internet,Wireless Internet,Air Con...
# Price                                                                        74.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               2.0
# Extra People                                                                  0.0
# Calendar Updated                                                      3 weeks ago
# Availability 30                                                              30.0
# Availability 60                                                              60.0
# Availability 90                                                              90.0
# Availability 365                                                            365.0
# Calendar last Scraped                                                  2016-01-04
# Number of Reviews                                                             8.0
# Review Scores Rating                                                         98.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                      flexible
# Calculated host listings count                                                1.0
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
# Restriction
#
# [36 rows x 14609 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14609 entries, 0 to 14779
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              14609 non-null  float64
#  1   Street                          14609 non-null  object
#  2   Smart Location                  14609 non-null  object
#  3   Country Code                    14609 non-null  object
#  4   Latitude                        14609 non-null  float64
#  5   Longitude                       14609 non-null  float64
#  6   Property Type                   14609 non-null  object
#  7   Room Type                       14609 non-null  object
#  8   Accommodates                    14609 non-null  float64
#  9   Bathrooms                       14609 non-null  float64
#  10  Bedrooms                        14609 non-null  float64
#  11  Beds                            14609 non-null  float64
#  12  Bed Type                        14609 non-null  object
#  13  Amenities                       14609 non-null  object
#  14  Price                           14609 non-null  float64
#  15  Cleaning Fee                    14609 non-null  float64
#  16  Guests Included                 14609 non-null  float64
#  17  Extra People                    14609 non-null  float64
#  18  Calendar Updated                14609 non-null  object
#  19  Availability 30                 14609 non-null  float64
#  20  Availability 60                 14609 non-null  float64
#  21  Availability 90                 14609 non-null  float64
#  22  Availability 365                14609 non-null  float64
#  23  Calendar last Scraped           14609 non-null  object
#  24  Number of Reviews               14609 non-null  float64
#  25  Review Scores Rating            14609 non-null  float64
#  26  Review Scores Accuracy          14609 non-null  float64
#  27  Review Scores Cleanliness       14609 non-null  float64
#  28  Review Scores Checkin           14609 non-null  float64
#  29  Review Scores Communication     14609 non-null  float64
#  30  Review Scores Location          14609 non-null  float64
#  31  Review Scores Value             14609 non-null  float64
#  32  Cancellation Policy             14609 non-null  object
#  33  Calculated host listings count  14609 non-null  float64
#  34  Features                        14609 non-null  object
#  35  Restriction                     14609 non-null  object
# dtypes: float64(24), object(12)
# memory usage: 4.6+ MB

# %%
df["Restriction"]
# Out:
# 0
# 1
# 2
# 3
# 4
#         ..
# 14775
# 14776
# 14777
# 14778
# 14779
# Name: Restriction, Length: 14609, dtype: object

# %% [markdown]
# ### 1.3.1. Transformación de varaibles categóricas.

# %% [markdown]
# Para poder llevar a cabo nuestra predicción tenemos además que transformar todas las variables catégoricas en numéricas.Esto lo haremos usando la herramienta LabelEncoder excepto para las variables 'Amenities' y 'Features'.

# %% [markdown]
# Para la variable Amenities y Features podemos contar el número de elementos que tiene cada una de estás variables, de esta manera cuantos mas elementos mejor.

# %%
# Creamos dos nuevas columnas llamadas 'Amenities_cat' y 'Features_cat' establecerla como vacía
df['Amenities_cat','Features_cat'] = ""

# %%
#Creamos una funcion que cuente los elementos
def count_elements(s):
    return len(s.split(','))
# Aplicar la función a cada fila del DataFrame
df['Amenities_cat'] = df['Amenities'].astype(str).apply(count_elements)
df['Features_cat'] = df['Features'].astype(str).apply(count_elements)
# Eliminar las columnas 'Amenities_cat' y 'Features_cat'
df=df.drop(['Amenities','Features'], axis=1)
# Imprimir el DataFrame con la nueva columna
df.T
# Out:
#                                                                             0      \
# ID                                                                     11210388.0
# Street                          Canyon Edge Drive, Austin, TX 78733, United St...
# Smart Location                                                         Austin, TX
# Country Code                                                                   US
# Latitude                                                                30.337361
# Longitude                                                              -97.863277
# Property Type                                                                Loft
# Room Type                                                         Entire home/apt
# Accommodates                                                                  2.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Price                                                                        58.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                            today
# Availability 30                                                              10.0
# Availability 60                                                              34.0
# Availability 90                                                              64.0
# Availability 365                                                            281.0
# Calendar last Scraped                                                  2017-03-06
# Number of Reviews                                                            42.0
# Review Scores Rating                                                         98.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                                      moderate
# Calculated host listings count                                                1.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                                  23
# Features_cat                                                                    4
#
#                                                             1      \
# ID                                                     17471131.0
# Street                          Barcelona, Barcelona 08010, Spain
# Smart Location                                   Barcelona, Spain
# Country Code                                                   ES
# Latitude                                                41.389683
# Longitude                                                2.172625
# Property Type                                           Apartment
# Room Type                                         Entire home/apt
# Accommodates                                                  4.0
# Bathrooms                                                     1.0
# Bedrooms                                                      1.0
# Beds                                                          1.0
# Bed Type                                                 Real Bed
# Price                                                        70.0
# Cleaning Fee                                                 40.0
# Guests Included                                               2.0
# Extra People                                                 44.0
# Calendar Updated                                            today
# Availability 30                                               6.0
# Availability 60                                              21.0
# Availability 90                                              39.0
# Availability 365                                            309.0
# Calendar last Scraped                                  2017-04-08
# Number of Reviews                                             1.0
# Review Scores Rating                                         80.0
# Review Scores Accuracy                                        8.0
# Review Scores Cleanliness                                    10.0
# Review Scores Checkin                                        10.0
# Review Scores Communication                                  10.0
# Review Scores Location                                        8.0
# Review Scores Value                                          10.0
# Cancellation Policy                               super_strict_30
# Calculated host listings count                              106.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                   7
# Features_cat                                                    3
#
#                                                             2      \
# ID                                                     17584891.0
# Street                          Barcelona, Barcelona 08008, Spain
# Smart Location                                   Barcelona, Spain
# Country Code                                                   ES
# Latitude                                                41.393035
# Longitude                                                2.162173
# Property Type                                           Apartment
# Room Type                                         Entire home/apt
# Accommodates                                                  4.0
# Bathrooms                                                     1.0
# Bedrooms                                                      1.0
# Beds                                                          1.0
# Bed Type                                                 Real Bed
# Price                                                        70.0
# Cleaning Fee                                                 60.0
# Guests Included                                               2.0
# Extra People                                                 42.0
# Calendar Updated                                            today
# Availability 30                                               7.0
# Availability 60                                              21.0
# Availability 90                                              42.0
# Availability 365                                            291.0
# Calendar last Scraped                                  2017-04-08
# Number of Reviews                                             0.0
# Review Scores Rating                                         94.0
# Review Scores Accuracy                                       10.0
# Review Scores Cleanliness                                    10.0
# Review Scores Checkin                                        10.0
# Review Scores Communication                                  10.0
# Review Scores Location                                       10.0
# Review Scores Value                                           9.0
# Cancellation Policy                               super_strict_30
# Calculated host listings count                              106.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                   7
# Features_cat                                                    3
#
#                                                             3      \
# ID                                                      5398030.0
# Street                          Barcelona, Barcelona 08009, Spain
# Smart Location                                   Barcelona, Spain
# Country Code                                                   ES
# Latitude                                                41.396967
# Longitude                                                2.167418
# Property Type                                           Apartment
# Room Type                                         Entire home/apt
# Accommodates                                                  8.0
# Bathrooms                                                     2.0
# Bedrooms                                                      3.0
# Beds                                                          4.0
# Bed Type                                                 Real Bed
# Price                                                       229.0
# Cleaning Fee                                                 79.0
# Guests Included                                               2.0
# Extra People                                                 39.0
# Calendar Updated                                            today
# Availability 30                                              11.0
# Availability 60                                              24.0
# Availability 90                                              47.0
# Availability 365                                            316.0
# Calendar last Scraped                                  2017-04-08
# Number of Reviews                                            13.0
# Review Scores Rating                                         92.0
# Review Scores Accuracy                                       10.0
# Review Scores Cleanliness                                     9.0
# Review Scores Checkin                                        10.0
# Review Scores Communication                                  10.0
# Review Scores Location                                       10.0
# Review Scores Value                                           9.0
# Cancellation Policy                                        strict
# Calculated host listings count                               24.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                  24
# Features_cat                                                    4
#
#                                                                             4      \
# ID                                                                     18104606.0
# Street                          L'Antiga Esquerra de l'Eixample, Barcelona, Ca...
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Latitude                                                                41.388685
# Longitude                                                                 2.15515
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  5.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      2.0
# Beds                                                                          2.0
# Bed Type                                                                 Real Bed
# Price                                                                       149.0
# Cleaning Fee                                                                 55.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                            today
# Availability 30                                                               0.0
# Availability 60                                                               0.0
# Availability 90                                                               0.0
# Availability 365                                                              7.0
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                             0.0
# Review Scores Rating                                                         94.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                      flexible
# Calculated host listings count                                               92.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                                  12
# Features_cat                                                                    5
#
#                                                                             5      \
# ID                                                                     15695269.0
# Street                          La Nova Esquerra de l'Eixample, Barcelona, Cat...
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Latitude                                                                41.382537
# Longitude                                                                2.149577
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  6.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      2.0
# Beds                                                                          3.0
# Bed Type                                                                 Real Bed
# Price                                                                       106.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                      2 weeks ago
# Availability 30                                                               0.0
# Availability 60                                                               2.0
# Availability 90                                                               2.0
# Availability 365                                                              4.0
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                             0.0
# Review Scores Rating                                                         94.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                               92.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                                   9
# Features_cat                                                                    5
#
#                                                                            6      \
# ID                                                                     1295958.0
# Street                          el Fort Pienc, Barcelona, Catalonia 08013, Spain
# Smart Location                                                  Barcelona, Spain
# Country Code                                                                  ES
# Latitude                                                               41.399058
# Longitude                                                               2.184229
# Property Type                                                          Apartment
# Room Type                                                        Entire home/apt
# Accommodates                                                                 5.0
# Bathrooms                                                                    2.0
# Bedrooms                                                                     3.0
# Beds                                                                         4.0
# Bed Type                                                                Real Bed
# Price                                                                       52.0
# Cleaning Fee                                                                60.0
# Guests Included                                                              4.0
# Extra People                                                                25.0
# Calendar Updated                                                           today
# Availability 30                                                              4.0
# Availability 60                                                             11.0
# Availability 90                                                             23.0
# Availability 365                                                           280.0
# Calendar last Scraped                                                 2017-04-08
# Number of Reviews                                                           43.0
# Review Scores Rating                                                        90.0
# Review Scores Accuracy                                                       9.0
# Review Scores Cleanliness                                                    9.0
# Review Scores Checkin                                                       10.0
# Review Scores Communication                                                 10.0
# Review Scores Location                                                       9.0
# Review Scores Value                                                          9.0
# Cancellation Policy                                                       strict
# Calculated host listings count                                               1.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                                 22
# Features_cat                                                                   4
#
#                                                                             7      \
# ID                                                                      1349311.0
# Street                          La Sagrada Família, Barcelona, Catalonia 08025...
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Latitude                                                                41.402357
# Longitude                                                                2.171119
# Property Type                                                           Apartment
# Room Type                                                            Private room
# Accommodates                                                                  2.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Price                                                                        45.0
# Cleaning Fee                                                                 30.0
# Guests Included                                                               1.0
# Extra People                                                                 20.0
# Calendar Updated                                                        yesterday
# Availability 30                                                              13.0
# Availability 60                                                              38.0
# Availability 90                                                              66.0
# Availability 365                                                             66.0
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                            29.0
# Review Scores Rating                                                         96.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                                      flexible
# Calculated host listings count                                                1.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                                  17
# Features_cat                                                                    3
#
#                                                                             8      \
# ID                                                                     15698621.0
# Street                          El Camp de l'Arpa del Clot, Barcelona, Catalun...
# Smart Location                                                   Barcelona, Spain
# Country Code                                                                   ES
# Latitude                                                                41.407356
# Longitude                                                                2.182982
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  6.0
# Bathrooms                                                                     2.0
# Bedrooms                                                                      2.0
# Beds                                                                          3.0
# Bed Type                                                                 Real Bed
# Price                                                                        80.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                       a week ago
# Availability 30                                                               0.0
# Availability 60                                                               0.0
# Availability 90                                                               2.0
# Availability 365                                                              2.0
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                             1.0
# Review Scores Rating                                                         80.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                        8.0
# Review Scores Value                                                           8.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                               92.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                                   9
# Features_cat                                                                    5
#
#                                                                         9      \
# ID                                                                  6766647.0
# Street                          Enfield Road, Austin, TX 78703, United States
# Smart Location                                                     Austin, TX
# Country Code                                                               US
# Latitude                                                            30.287124
# Longitude                                                          -97.768164
# Property Type                                                           House
# Room Type                                                     Entire home/apt
# Accommodates                                                              6.0
# Bathrooms                                                                 2.0
# Bedrooms                                                                  3.0
# Beds                                                                      3.0
# Bed Type                                                             Real Bed
# Price                                                                   795.0
# Cleaning Fee                                                            250.0
# Guests Included                                                           1.0
# Extra People                                                              0.0
# Calendar Updated                                                        today
# Availability 30                                                          21.0
# Availability 60                                                          51.0
# Availability 90                                                          81.0
# Availability 365                                                        356.0
# Calendar last Scraped                                              2017-03-06
# Number of Reviews                                                         1.0
# Review Scores Rating                                                    100.0
# Review Scores Accuracy                                                   10.0
# Review Scores Cleanliness                                                10.0
# Review Scores Checkin                                                    10.0
# Review Scores Communication                                              10.0
# Review Scores Location                                                   10.0
# Review Scores Value                                                      10.0
# Cancellation Policy                                                    strict
# Calculated host listings count                                            1.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                              24
# Features_cat                                                                3
#
#                                 ...                              14770  \
# ID                              ...                         16877299.0
# Street                          ...  Sineu, Illes Balears 07510, Spain
# Smart Location                  ...                       Sineu, Spain
# Country Code                    ...                                 ES
# Latitude                        ...                          39.646497
# Longitude                       ...                           2.992312
# Property Type                   ...                              House
# Room Type                       ...                    Entire home/apt
# Accommodates                    ...                                8.0
# Bathrooms                       ...                                1.0
# Bedrooms                        ...                                3.0
# Beds                            ...                                6.0
# Bed Type                        ...                           Real Bed
# Price                           ...                               90.0
# Cleaning Fee                    ...                               60.0
# Guests Included                 ...                                6.0
# Extra People                    ...                               20.0
# Calendar Updated                ...                              today
# Availability 30                 ...                               17.0
# Availability 60                 ...                               43.0
# Availability 90                 ...                               73.0
# Availability 365                ...                              348.0
# Calendar last Scraped           ...                         2017-03-15
# Number of Reviews               ...                                0.0
# Review Scores Rating            ...                               94.0
# Review Scores Accuracy          ...                               10.0
# Review Scores Cleanliness       ...                               10.0
# Review Scores Checkin           ...                               10.0
# Review Scores Communication     ...                               10.0
# Review Scores Location          ...                               10.0
# Review Scores Value             ...                                9.0
# Cancellation Policy             ...                             strict
# Calculated host listings count  ...                                1.0
# Restriction                     ...
# (Amenities_cat, Features_cat)   ...
# Amenities_cat                   ...                                 27
# Features_cat                    ...                                  3
#
#                                                               14771  \
# ID                                                        4152647.0
# Street                          Pina, Balearic Islands 07220, Spain
# Smart Location                                          Pina, Spain
# Country Code                                                     ES
# Latitude                                                  39.595354
# Longitude                                                  2.927612
# Property Type                                                 House
# Room Type                                           Entire home/apt
# Accommodates                                                    2.0
# Bathrooms                                                       2.0
# Bedrooms                                                        1.0
# Beds                                                            1.0
# Bed Type                                                   Real Bed
# Price                                                         160.0
# Cleaning Fee                                                   50.0
# Guests Included                                                 1.0
# Extra People                                                   70.0
# Calendar Updated                                       5 months ago
# Availability 30                                                30.0
# Availability 60                                                60.0
# Availability 90                                                90.0
# Availability 365                                              365.0
# Calendar last Scraped                                    2017-03-15
# Number of Reviews                                               0.0
# Review Scores Rating                                           94.0
# Review Scores Accuracy                                         10.0
# Review Scores Cleanliness                                      10.0
# Review Scores Checkin                                          10.0
# Review Scores Communication                                    10.0
# Review Scores Location                                         10.0
# Review Scores Value                                             9.0
# Cancellation Policy                                          strict
# Calculated host listings count                                  3.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                    18
# Features_cat                                                      2
#
#                                                                14772  \
# ID                                                         1501761.0
# Street                          Petra, Balearic Islands 07520, Spain
# Smart Location                                          Petra, Spain
# Country Code                                                      ES
# Latitude                                                   39.604911
# Longitude                                                   3.097125
# Property Type                                                  House
# Room Type                                            Entire home/apt
# Accommodates                                                    10.0
# Bathrooms                                                        4.0
# Bedrooms                                                         4.0
# Beds                                                             7.0
# Bed Type                                                    Real Bed
# Price                                                          196.0
# Cleaning Fee                                                    25.0
# Guests Included                                                  1.0
# Extra People                                                     0.0
# Calendar Updated                                               today
# Availability 30                                                 30.0
# Availability 60                                                 60.0
# Availability 90                                                 90.0
# Availability 365                                               316.0
# Calendar last Scraped                                     2017-03-15
# Number of Reviews                                                3.0
# Review Scores Rating                                            80.0
# Review Scores Accuracy                                           8.0
# Review Scores Cleanliness                                        9.0
# Review Scores Checkin                                            7.0
# Review Scores Communication                                      5.0
# Review Scores Location                                           9.0
# Review Scores Value                                              8.0
# Cancellation Policy                                           strict
# Calculated host listings count                                 129.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                     14
# Features_cat                                                       4
#
#                                                                     14773  \
# ID                                                              1010498.0
# Street                          Balearic Islands, Balearic Islands, Spain
# Smart Location                                    Balearic Islands, Spain
# Country Code                                                           ES
# Latitude                                                        39.740432
# Longitude                                                        2.931212
# Property Type                                                       House
# Room Type                                                 Entire home/apt
# Accommodates                                                          8.0
# Bathrooms                                                             3.0
# Bedrooms                                                              4.0
# Beds                                                                  8.0
# Bed Type                                                         Real Bed
# Price                                                               260.0
# Cleaning Fee                                                         60.0
# Guests Included                                                       1.0
# Extra People                                                          0.0
# Calendar Updated                                                    today
# Availability 30                                                      30.0
# Availability 60                                                      60.0
# Availability 90                                                      64.0
# Availability 365                                                    284.0
# Calendar last Scraped                                          2017-03-15
# Number of Reviews                                                     0.0
# Review Scores Rating                                                 94.0
# Review Scores Accuracy                                               10.0
# Review Scores Cleanliness                                            10.0
# Review Scores Checkin                                                10.0
# Review Scores Communication                                          10.0
# Review Scores Location                                               10.0
# Review Scores Value                                                   9.0
# Cancellation Policy                                                strict
# Calculated host listings count                                      129.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                          10
# Features_cat                                                            5
#
#                                                                             14774  \
# ID                                                                      6292515.0
# Street                          Ditmars / Steinway, Queens, NY 11105, United S...
# Smart Location                                                         Queens, NY
# Country Code                                                                   US
# Latitude                                                                40.771787
# Longitude                                                              -73.898799
# Property Type                                                           Apartment
# Room Type                                                            Private room
# Accommodates                                                                  1.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Price                                                                        40.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                    11 months ago
# Availability 30                                                               0.0
# Availability 60                                                               0.0
# Availability 90                                                               0.0
# Availability 365                                                              0.0
# Calendar last Scraped                                                  2017-05-02
# Number of Reviews                                                             1.0
# Review Scores Rating                                                         80.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                                      moderate
# Calculated host listings count                                                1.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                                  13
# Features_cat                                                                    5
#
#                                                                             14775  \
# ID                                                                      2098030.0
# Street                          Bedford-Stuyvesant, Brooklyn, NY 11213, United...
# Smart Location                                                       Brooklyn, NY
# Country Code                                                                   US
# Latitude                                                                40.678945
# Longitude                                                              -73.939342
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                  2.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          2.0
# Bed Type                                                                 Real Bed
# Price                                                                        90.0
# Cleaning Fee                                                                 60.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                       5 days ago
# Availability 30                                                               7.0
# Availability 60                                                              34.0
# Availability 90                                                              64.0
# Availability 365                                                            339.0
# Calendar last Scraped                                                  2017-05-02
# Number of Reviews                                                            30.0
# Review Scores Rating                                                         95.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                        9.0
# Review Scores Value                                                          10.0
# Cancellation Policy                                                        strict
# Calculated host listings count                                                1.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                                  11
# Features_cat                                                                    4
#
#                                                                             14776  \
# ID                                                                     17989442.0
# Street                          Porte de Versailles, Paris, Île-de-France 7501...
# Smart Location                                                      Paris, France
# Country Code                                                                   FR
# Latitude                                                                48.836197
# Longitude                                                                2.294045
# Property Type                                                     Bed & Breakfast
# Room Type                                                            Private room
# Accommodates                                                                  1.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          2.0
# Bed Type                                                                 Real Bed
# Price                                                                        75.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               1.0
# Extra People                                                                  0.0
# Calendar Updated                                                       3 days ago
# Availability 30                                                              17.0
# Availability 60                                                              47.0
# Availability 90                                                              77.0
# Availability 365                                                             78.0
# Calendar last Scraped                                                  2017-04-06
# Number of Reviews                                                             0.0
# Review Scores Rating                                                         94.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                      flexible
# Calculated host listings count                                                1.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                                  11
# Features_cat                                                                    3
#
#                                                        14777  \
# ID                                                13278634.0
# Street                          Paris, Île-de-France, France
# Smart Location                                 Paris, France
# Country Code                                              FR
# Latitude                                           48.888809
# Longitude                                           2.316173
# Property Type                                      Apartment
# Room Type                                    Entire home/apt
# Accommodates                                             5.0
# Bathrooms                                                1.0
# Bedrooms                                                 2.0
# Beds                                                     3.0
# Bed Type                                            Real Bed
# Price                                                  100.0
# Cleaning Fee                                            40.0
# Guests Included                                          3.0
# Extra People                                            10.0
# Calendar Updated                                  5 days ago
# Availability 30                                          7.0
# Availability 60                                         18.0
# Availability 90                                         29.0
# Availability 365                                        97.0
# Calendar last Scraped                             2017-04-05
# Number of Reviews                                       17.0
# Review Scores Rating                                    94.0
# Review Scores Accuracy                                  10.0
# Review Scores Cleanliness                               10.0
# Review Scores Checkin                                   10.0
# Review Scores Communication                             10.0
# Review Scores Location                                  10.0
# Review Scores Value                                     10.0
# Cancellation Policy                                   strict
# Calculated host listings count                           1.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                             17
# Features_cat                                               3
#
#                                                                           14778  \
# ID                                                                   10733941.0
# Street                          Gaylord Street, Denver, CO 80206, United States
# Smart Location                                                       Denver, CO
# Country Code                                                                 US
# Latitude                                                              39.742205
# Longitude                                                           -104.959933
# Property Type                                                         Apartment
# Room Type                                                       Entire home/apt
# Accommodates                                                                4.0
# Bathrooms                                                                   1.0
# Bedrooms                                                                    1.0
# Beds                                                                        2.0
# Bed Type                                                               Real Bed
# Price                                                                      99.0
# Cleaning Fee                                                               10.0
# Guests Included                                                             2.0
# Extra People                                                               10.0
# Calendar Updated                                                      yesterday
# Availability 30                                                             0.0
# Availability 60                                                             0.0
# Availability 90                                                             0.0
# Availability 365                                                           14.0
# Calendar last Scraped                                                2016-05-18
# Number of Reviews                                                           1.0
# Review Scores Rating                                                      100.0
# Review Scores Accuracy                                                     10.0
# Review Scores Cleanliness                                                  10.0
# Review Scores Checkin                                                      10.0
# Review Scores Communication                                                10.0
# Review Scores Location                                                     10.0
# Review Scores Value                                                        10.0
# Cancellation Policy                                                    moderate
# Calculated host listings count                                              1.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                                18
# Features_cat                                                                  3
#
#                                                                             14779
# ID                                                                      4637801.0
# Street                          35th Avenue Northeast, Seattle, WA 98105, Unit...
# Smart Location                                                        Seattle, WA
# Country Code                                                                   US
# Latitude                                                                47.672327
# Longitude                                                             -122.291451
# Property Type                                                               House
# Room Type                                                            Private room
# Accommodates                                                                  2.0
# Bathrooms                                                                     1.0
# Bedrooms                                                                      1.0
# Beds                                                                          1.0
# Bed Type                                                                 Real Bed
# Price                                                                        74.0
# Cleaning Fee                                                                 25.0
# Guests Included                                                               2.0
# Extra People                                                                  0.0
# Calendar Updated                                                      3 weeks ago
# Availability 30                                                              30.0
# Availability 60                                                              60.0
# Availability 90                                                              90.0
# Availability 365                                                            365.0
# Calendar last Scraped                                                  2016-01-04
# Number of Reviews                                                             8.0
# Review Scores Rating                                                         98.0
# Review Scores Accuracy                                                       10.0
# Review Scores Cleanliness                                                    10.0
# Review Scores Checkin                                                        10.0
# Review Scores Communication                                                  10.0
# Review Scores Location                                                       10.0
# Review Scores Value                                                           9.0
# Cancellation Policy                                                      flexible
# Calculated host listings count                                                1.0
# Restriction
# (Amenities_cat, Features_cat)
# Amenities_cat                                                                  21
# Features_cat                                                                    4
#
# [37 rows x 14609 columns]

# %% [markdown]
# Además la variable 'Street' parece que va a aportar mucha variabilidad, por tanto va a debilitar nuestras predicciones, por ello la eliminamos.

# %%
df=df.drop(['Street'],axis=1)

# %% [markdown]
# ### 1.4. Detección y tratamiento de Outliers.

# %% [markdown]
# ## 2. Calculo del precio dadas las características.

# %% [markdown]
# Nuestro problema inicial es tratar de determinar el precio de un apartamento dadas las característica de este. Como ya sabemos existen varios métodos para realizar este procedimiento. En nuestro caso particular trataremos de hacerlo mediante dos métodos distintos, en primer lugar con una regresión lineal y en segundo lugar con una red neuronal.

# %% [markdown]
# ### 2.1. División del conjunto de datos.

# %% [markdown]
# Como es habitual en los problemas de predicción, en este primer paso dividimos los datos en tres subconjuntos entrenamiento, validación y test. Para ello usamos la función train_val_test_split.

# %%
def train_val_test_split(df, rstate=42, shuffle=True, stratify=None):
    strat = df[stratify] if stratify else None
    train_set, test_set = train_test_split(
        df, test_size=0.3, random_state=rstate, shuffle=shuffle, stratify=strat)
    strat = test_set[stratify] if stratify else None
    val_set, test_set = train_test_split(
        test_set, test_size=0.5, random_state=rstate, shuffle=shuffle, stratify=strat)
    return (train_set, val_set, test_set)

# %%
from sklearn.model_selection import train_test_split
train_set, val_set, test_set = train_val_test_split(df)

# %% [markdown]
# A continuación separamos las etiquetas de las características de entrada para cada uno de los subconjuntos.

# %%
# Conjunto de datos general
X_df = df.drop("Price", axis=1)
y_df = df["Price"].copy()

# %%
# Conjunto de datos de entrenamiento
X_train = train_set.drop("Price", axis=1)
y_train = train_set["Price"].copy()

# %%
# Conjunto de datos de validación
X_val = val_set.drop("Price", axis=1)
y_val = val_set["Price"].copy()

# %%
# Conjunto de datos de pruebas
X_test = test_set.drop("Price", axis=1)
y_test = test_set["Price"].copy()

# %%
print('Datos entrenamiento: ', X_train.shape)
print('Datos validacion: ', X_val.shape)
print('Datos test: ', X_test.shape)
# Out:
# Datos entrenamiento:  (10226, 35)
# Datos validacion:  (2191, 35)
# Datos test:  (2192, 35)

# %% [markdown]
# ### 2.2. Regresión Lineal.

# %% [markdown]
# Para mejorar la predicción de nuestro modelo transformamos la variable dependiente 'Price' en logaritmo.

# %%
y_df=np.log(y_df)
y_train=np.log(y_train)
y_val=np.log(y_val)
y_test=np.log(y_test)

# %% [markdown]
# Ahora procedemos a estimar nuestro modelo de regresión lineal:

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# C:\Users\crist\anaconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14152\2231432609.py in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 reg = LinearRegression()
# ----> 3 reg.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     962         raise ValueError("y cannot be None")
#     963
# --> 964     X = check_array(
#     965         X,
#     966         accept_sparse=accept_sparse,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    2062
#    2063     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064         return np.asarray(self._values, dtype=dtype)
#    2065
#    2066     def __array_wrap__(
#
# ValueError: could not convert string to float: 'Madrid, Spain'

# %%
y_pred_train=reg.predict(X_train)
y_pred_test=reg.predict(X_test)
y_pred_val=reg.predict(X_val)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

#RMSE
train_rmse = mean_squared_error(y_train, y_pred_train, squared=False)
test_rmse = mean_squared_error(y_test, y_pred_test, squared=False)
val_rmse = mean_squared_error(y_val, y_pred_val, squared=False)

#MAE
train_mae = mean_absolute_error(y_train, y_pred_train)
test_mae = mean_absolute_error(y_test, y_pred_test)
val_mae = mean_absolute_error(y_val, y_pred_val)

#R2
train_r2 = r2_score(y_train, y_pred_train)
test_r2 = r2_score(y_test, y_pred_test)
val_r2 =r2_score(y_val, y_pred_val)

# %%
print("Vemos como de bueno es el entrenamiento:")
print("El Rmse del entrenamiento del modelo es:", train_rmse)
print("El mae del entrenamiento del modelo es:", train_mae)
print("El R2 del entrenamiento del modelo es:", train_r2)

# %%
print("RMSE:")
print("El Rmse del test del modelo es:",test_rmse)
print("El Rmse de la validación del modelo es:",val_rmse)
print("MAE:")
print("El mae del test del modelo es:",test_mae)
print("El mae de la validación del modelo es:",val_mae)
print("R2:")
print("El R2 del test del modelo es:",test_r2)
print("El R2 de la validación del modelo es:",val_r2)

# %% [markdown]
# ### 2.3. Red Neuronal.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

# %%
model.compile(optimizer='adam', loss='mean_squared_error',metrics=['mae', 'mse'])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32)

# %%
train_loss, train_mae, train_mse = model.evaluate(X_train, y_train)
val_loss, val_mae, val_mse = model.evaluate(X_val, y_val)
test_loss, test_mae, test_mse = model.evaluate(X_test, y_test)

# %%
print('Train MAE:', train_mae)
print('Train MSE:', train_mse)
print('Validation MAE:', val_mae)
print('Validation MSE:', val_mse)
print('Test MAE:', test_mae)
print('Test MSE:', test_mse)

# %% [markdown]
# ## 3. Clasificador dado el precio y las características.

# %% [markdown]
# A partir de los resultados obtenidos por la red neuronal en el apartado 2 vamos a tratar de realizar un problema de clasificación mediante otra red neuronal. Para ello crearemos unos umbrales para los cuales nuestra red clasificara las ofertas de apartamento en tres grupos:
#  - Super Precio
#  - Timo
#  - Precio Justo

# %% [markdown]
# ## 4. Conclusión.
